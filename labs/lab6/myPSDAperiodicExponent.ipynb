# %% [markdown]
# # Power Spectral Density (PSD)
# The Power Spectral Density (PSD) describes how the power of a signal is distributed across different frequencies. It is a fundamental tool in signal analysis, especially when characterizing the frequency content of complex time series, such as those encountered in neuroscience, engineering, and physics.
#
# In the context of neural signals (*e.g.*, EEG or LFP), the PSD allows us to quantify the presence and strength of oscillatory activity within specific frequency bands, providing a compact and informative representation of the underlying dynamics.
#
# ### Welch's method
# Welch's method estimates the PSD by dividing the signal into overlapping segments, applying a window to each, computing their individual spectra, and averaging them. This reduces variance compared to a single FFT, at the cost of frequency resolution.

# %% [markdown]
# ### Install the libraries `mne` and `fooof`
# We will use the following Python libraries:
#
# * `mne`: A powerful library for processing and analyzing electrophysiological data (EEG, MEG, etc.). It provides functions for loading data, computing power spectral density (PSD), and visualizing brain signals.
#
# * `fooof` : The Fitting Oscillations and One Over F (FOOOF) toolbox is used to separate periodic (oscillatory) and aperiodic (1/f-like) components in power spectra. It helps quantify neural oscillations independently from the background spectral slope.

# %%
# !pip install -q fooof mne

# %%
# Nasconde gli ImportWarning
import warnings
warnings.filterwarnings('ignore', category=ImportWarning)

# %% [markdown]
# ### Warnings When Importing `fooof`
#
# You may see several warnings when importing `fooof`. This is normal and due to how its dependencies load, especially in Colab. They don't affect functionality.
#
# 👉 Tip: **Run the import cell twice** to help clear these warnings.

# %%
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Core libraries
import numpy as np
import scipy
import matplotlib.pyplot as plt
import mne
import fooof

mne.set_log_level('error') # Suppress MNE info and warning messages for cleaner output
# Out:
# C:\Users\simon\AppData\Local\Temp\ipykernel_10280\2590640846.py:10: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   import fooof
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 10
#       8 import matplotlib.pyplot as plt
#       9 import mne
# ---> 10 import fooof
#      12 mne.set_log_level('error') # Suppress MNE info and warning messages for cleaner output
#
# File c:\Users\simon\UniGe\nsa\neural-signal-analysis-notes\labs\.venv\Lib\site-packages\fooof\__init__.py:16
#      13 warn(DEPRECATION_TEXT, DeprecationWarning, stacklevel=2)
#      15 from .bands import Bands
# ...

# %% [markdown]
# ## Compute the Power Spectral Density

# %% [markdown]
# ### Load the EEG data and define the parameters

# %% [markdown]
# The EEG data used in this notebook come from an open-access dataset of infants published by  [Xiao et al. 2018](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0190276).
#
# 📂 Dataset: [infant EEG data](https://figshare.com/articles/dataset/infant_EEG_data/5598814/1).
#
# The recordings are already preprocessed and ready for analysis.

# %%
# Load raw EEG data
raw = mne.io.read_raw_fif('./data/sub01_ses02_raw.fif', preload=True);

# Display basic information about the recording
print(raw.info)
print('--------------')

# Get the sampling frequency
sfreq = raw.info['sfreq']

# Extract data as a NumPy array (shape: n_channels x n_samples)
data = raw.get_data()
n_chs, n_samples = data.shape

# Compute and display signal duration
duration_sec = n_samples / sfreq
minutes = int(duration_sec // 60)
seconds = int(duration_sec % 60)

print(f'Sampling frequency: {sfreq} Hz')
print(f'Data shape: {n_chs} channels × {n_samples} samples')
print(f'Duration of the recording: {minutes} min {seconds} sec')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Load raw EEG data
# ----> 2 raw = mne.io.read_raw_fif('./data/sub01_ses02_raw.fif', preload=True);
#       4 # Display basic information about the recording
#       5 print(raw.info)
#
# File c:\Users\simon\UniGe\nsa\neural-signal-analysis-notes\labs\.venv\Lib\site-packages\lazy_loader\__init__.py:82, in attach.<locals>.__getattr__(name)
#      80 elif name in attr_to_modules:
#      81     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82     submod = importlib.import_module(submod_path)
#      83     attr = getattr(submod, name)
#      85     # If the attribute lives in a file (module) with the same
#      86     # name as the attribute, ensure that the attribute and *not*
#      87     # the module is accessible on the package.
#
# ...

# %% [markdown]
# ### Compute Power Spectral Density (PSD) using Welch's Method
# We estimate the PSD of the EEG data using **Welch's method**, which averages over overlapping windows to reduce variance.
# The frequency range is set from 1 to 30 Hz, as the signal has been band-pass filtered between 0.5 and 30 Hz—therefore, no meaningful spectral content exists outside this range.
# The PSD is plotted in decibels (dB) for clearer visualization.

# %%
# Define parameters
fmin = 1
fmax = 30

# Compute the Power Spectral Density (PSD)
psd = ...

# Plot the PSD

# %% [markdown]
# ### Identify the Linear Range in Log-Log Space
# To analyze the **aperiodic (1/f-like)** components of the power spectrum, we need to focus on the part of the PSD that appears linear in log-log space ([Donoghue et al. 2020](https://www.nature.com/articles/s41593-020-00744-x)).
# In the previous plot, the PSD is shown on a linear frequency scale, which makes it harder to identify the linear region of the aperiodic background.
#
# Now, plot the PSD using log-log axes (log-frequency vs. log-power) to visually determine the frequency range where the spectrum follows a linear trend.
# This range will be used later to accurately fit the aperiodic component using the `fooof` toolbox.

# %%
# Extract the PSD data and frequency values
psd_data = ...
psd_freqs = ...

# Plot the PSD in log-log space

# %% [markdown]
# ### Fit aperiodic components using `fooof`
# In this step, we will fit the aperiodic component of the Power Spectral Density (PSD) using the fooof toolbox ([FOOOF - fitting oscillations & one over f](https://fooof-tools.github.io/fooof/#fooof-fitting-oscillations-one-over-f)).
#
# `max_n_peaks = n`: This parameter limits the model to detect up to `n` oscillatory peaks.
#
# Fitting the Model: The `fit()` method fits the model to the PSD data, separating the aperiodic and oscillatory components.
#
# Extract Parameters: After fitting, you will extract the following parameters:
#
#   * Exponent: Represents the slope of the aperiodic component.
#
#   * Offset: Represents the offset of the aperiodic component.
#
#   * $\text{R}^2$: The goodness-of-fit value, indicating how well the model explains the data.
#
# You should now apply this method to estimate the aperiodic component and interpret the extracted parameters.

# %%
# Initialize the FOOOFGroup
fm = ...

# Define the frequency range for fitting (this range should be chosen based on your data and analysis)
fmin_fit = ...
fmax_fit = ...

# Fit the FOOOF model to the PSD data for the specified frequency range
...

# Extract the parameters of the aperiodic component
exponent = ...
offset = ...

# Extract the R-squared value to assess the goodness of fit
rsquare = ...

# %% [markdown]
# ### Print results

# %%
# Print out a report

# %% [markdown]
# After fitting the model, we can visualize the results for a specific subject or dataset.
#
# * Plot the raw PSD data with the fitted aperiodic and oscillatory components.
#
# * Plot the same fit, but in log-log space to better examine the aperiodic component and the model's fit in this scale.
#
# These visualizations will help us understand how well the FOOOF model fits the data and how the aperiodic component behaves.

# %%
# Retrieve the FOOOF object for a specific channel
fc = ...

# Plot the fitting
